# %% [markdown]
# Multiple Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv(r"/content/multiple_linear_regression_dataset.csv")
data.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
data.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
x=data.iloc[:,:-1]
x.head(2)
# Out:
#    age  experience
# 0   25           1
# 1   30           3

# %%
y=data.iloc[:,[2]]
y.head(2)
# Out:
#    income
# 0   30450
# 1   35670

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=1/4,random_state=0)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
y_prediction=model.predict(x_test)
y_prediction
model.score(x_test,y_test)
# Out:
# 0.9359144572356176
